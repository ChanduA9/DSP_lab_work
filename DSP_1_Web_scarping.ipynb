# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 934.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 8.7 MB/s eta 0:00:00
# ...

# %%
# import pandas as pd
# import pickle
# import matplotlib.pyplot as plt
import openai

# %%
class students_data:
  def __init__(self,students_data):
    self.students_data=students_data

  def students_dataset(self):
    try:
      menu=" 1.Summary \n 2.Bar chart between marks and grades \n 3.Passed students \n 4.Failed students \n 5.Add or delete  the new row/column"
      print(menu)
      options=int(input("Enter your option:"))
      if (options==1):
        summary=pd.students_data.info()
      elif (option==2):
        graphs_data=plt.hist(x="marks",y="grades")
        graphs_data.show()
      elif (option==3):
        if(students_data['marks']<35):
          passed_students_data=students_data['names']

# %%
def fun(series_data):
  return series_data
  print(dataframe_data['names'])

grade_data=[]
marks_data=[]
students=['Vikram','Vicky','Vikrant']
for i in range(len(students)):
  grades=str(input("Enter the students grades:"))
  marks=int(input("Enter the students marks:"))
  grade_data.append(grades)
  marks_data.append(marks)
students_data={'names':students,'grades':grade_data,'marks':marks_data}
series_data=pd.Series(students_data,index=('names','grades','marks'))
dataframe_data=pd.DataFrame(series_data)
f=open('data.csv','wb')
# print(dataset)
dataset=pickle.dump(dataframe_data,f)
f.close()
print(series_data['names'])
# print(dataframe_data)
fun(dataframe_data)

# %%
def Exp(n2):
  global n1
  n1,n2=n1+5,n2+10
  print(n1,n2,end='')
n1=10
Exp(n1)
print(n1)
# Out:
# 15 2015

# %%
l=['Basic','C','C++']
p=l.sort()
print(p)
# Out:
# None

# %%
import math
print(math.fabs(10))
# Out:
# 10.0

# %%
import requests
from bs4 import BeautifulSoup
import html5lib as html
import csv

# %%
url="https://spoonreport.com/flavor-index/"
data=requests.get(url)
url_data=data.content
print(url_data)
# Out:
# b'400 - Bad Request | Your browser sent a request this server could not understand.\n'

# %%
#scraping the data from the url
data=BeautifulSoup(url_data,'lxml')
clean_data=data.find_all('span')
scraped_data=BeautifulSoup(str(clean_data),'lxml').get_text().split(", ")
# print(scraped_data)
for scrap in scraped_data:
  print(scrap)
# Out:
# []

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>"""

# %%
# !pip install html5lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
URL="http://www.values.com/inspirational-quotes"
r=requests.get(URL)
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" dir="ltr" lang="en-US">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width,initial-scale=1.0" />\n  <title>Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life</title>\n<meta name="description" content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors.">\n<meta name="keywords" content="pass, it, on, passiton, values, kindness">\n<meta name="twitter:site_name" content="The Foundation for a Better Life">\n<meta name="twitter:site" content="@passiton_values">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:description" content="Thank you for visiting.">\n<meta name="twitter:image" content="https://www.passiton.com/passiton_fbl.jpg">\n<meta property="og:url" content="https://www.passiton
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.content,'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
#   <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
#   <meta content="@passiton_values" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Thank you for visiting." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" name="twitter:image"/>
# ...

# %%
quotes=[]
table=soup.find('div',attrs={'id':'all_quotes'})
print(table)

for row in table.findAll('div',attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
  print(row)
quote={}
# Out:
# <div class="row" id="all_quotes">
#
#           <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#
#             <a href="/inspirational-quotes/7237-if-your-compassion-does-not-include-yourself"><img alt="If your compassion does not include yourself, it is incomplete. #&lt;Author:0x0000564dbe4d53e8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7237/medium/20230504_thursday_quote.jpg" width="310"/></a>
#             <h5 class="value_on_red"><a href="/inspirational-quotes/7237-if-your-compassion-does-not-include-yourself">SELF-CARE</a></h5>
#
#           </div>
#
#
#           <div class="col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top">
#
# ...

# %%
quote['theme'] = table.h5.text
quote['url']=table.a['href']
quote['img']=table.img['src']
quote['lines']=table.img['alt'].split(" #")[0]
quote['author']=table.img['alt'].split(" #")[0]
quotes.append(quote)

# %%
print(quotes)
# Out:
# [{'theme': 'SELF-CARE', 'url': '/inspirational-quotes/7237-if-your-compassion-does-not-include-yourself', 'img': 'https://assets.passiton.com/quotes/quote_artwork/7237/medium/20230504_thursday_quote.jpg', 'lines': 'If your compassion does not include yourself, it is incomplete.', 'author': 'If your compassion does not include yourself, it is incomplete.'}]

# %%
filename='inspirational_quotes.csv'
with open(filename,'w', newline='') as f:
  w=csv.DictWriter(f,['theme','url','img','lines','author'])
  w.writeheader()
  for quote in quotes:
    w.writerow(quote)

# %%
import pandas as pd
import random as rd

# %%
data=pd.read_csv('cse_06.csv')
print(data)
marks_data=rd.randint(1,100)
print(marks_data)
# Out:
#     S.NO    ID.NO                 Name of the Student BRANCH SECTION
# 0      1  N190011               NEDUNURI SNEHAMADHURI    CSE  CSE-06
# 1      2  N190058                     KUDDANA PALLAVI    CSE  CSE-06
# 2      3  N190075            VEERESWARAPU ASHA JYOTHI    CSE  CSE-06
# 3      4  N190096                KONTHALA AKHIL KUMAR    CSE  CSE-06
# 4      5  N190108                      BHAVANA BEHARA    CSE  CSE-06
# 5      6  N190110                    PULAKALA JAYARAM    CSE  CSE-06
# 6      7  N190112                     SRIRAM PHANISRI    CSE  CSE-06
# 7      8  N190118                      TALARI NANDINI    CSE  CSE-06
# 8      9  N190127                      GUTHULA LOKESH    CSE  CSE-06
# 9     10  N190234                     NAGARAJU HARIKA    CSE  CSE-06
# 10    11  N190239                       KETHA SRAVANI    CSE  CSE-06
# 11    12  N190270                 KOTA BHANU SRIVALLI    CSE  CSE-06
# 12    13  N190272               KOMMANAPALLI JYOTHSNA    CSE  CSE-06
# ...

# %%
with open('cse_06.csv','w+') as f:
  s=f.readlines()
  print(s[0:100])
  for i  in range(1,100):
    marks_data=str(i)
    f.write(marks_data)
  #  f.close()
# Out:
# []

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# %%
# os.chdir('gdrive/My Drive/santhosh')
# os.getcwd()

# %%
def os_fun():
  #change directory
  print(os.getcwd()) #current directory
  with open('filename.txt','w+') as f:
    f.write('python is programming language and it can be used   in Data Science and Machine Learning.Pythons expressions include:The +, -, and * operators for mathematical addition, subtraction, and multiplication are similar to other languages, but the behavior of division differs. There are two types of divisions in Python: floor division (or integer division) // and floating-point/division.[91] Python uses the ** operator for exponentiation.Python uses the + operator for string concatenation. Python uses the * operator for duplicating a string a specified number of times.The @ infix operator. It is intended to be used by libraries such as NumPy for matrix multiplication.')
    # print(f.seek(0,2))
    # f.seek(5)
    # print(f.tell())
    print(f.read())
    # i=1
    # for lines in f.readlines():
    #   for line in lines:
    #     if (i%2==1):
    #       print(lines)



# os.chdir('gdrive/My Drive/santhosh')
os_fun()
# Out:
# /content

# %%
# def read_lines():
#   #reading the odd lines
#   i=1
#   for lines in f:
#     if(i%2==1):
#       print(lines)
#     i+=1

# read_lines()

# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.DataFrame(a,columns=('Name','Subject','Marks'))
dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f7e3d2db5519> in <cell line: 1>()
# ----> 1 dataframe=pd.DataFrame(a,columns=('Name','Subject','Marks'))
#       2 dataframe
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     720                 )
#     721             else:
# --> 722                 mgr = ndarray_to_mgr(
#     723                     data,
#     724                     index,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     347     )
#     348
# --> 349     _check_values_indices_shape_match(values, index, columns)
#     350
#     351     if typ == "array":
#
# ...

# %%
print(dataframe.iloc[0])
# Out:
# x    1
# y    2
# Name: a, dtype: int64

# %%
print(dataframe.loc[:,['x','y']])
# Out:
#    x  y
# a  1  2
# b  1  3
# c  5  6

# %%
print(dataframe.iloc[:])
print(dataframe.iloc[:,[0,1]])
print("\n\n")
print(dataframe.iloc[0:2,[0,1]])
print(dataframe.loc[['a','b'],['x','y']])
# Out:
#    x  y
# a  1  2
# b  1  3
# c  5  6
#    x  y
# a  1  2
# b  1  3
# c  5  6
#
#
#
#    x  y
# a  1  2
# b  1  3
#    x  y
# a  1  2
# b  1  3

# %%
print(dataframe.iloc[0,0])
# print(dataframe.loc['x','y'])
print(dataframe.iat[0,0])
print(dataframe.at['a','x'])
# Out:
# 1
# 1
# 1

# %%
dataframe['d']=[1,4,6]
print(dataframe)
print(dataframe.drop('c',axis=0))
print(dataframe.drop('b'))
# dataframe['y','c']=[3,4]
print('\n\n')
print(dataframe.loc['b'])
# Out:
#    x  y  d
# a  1  2  1
# b  1  3  4
# c  5  6  6
#    x  y  d
# a  1  2  1
# b  1  3  4
#    x  y  d
# a  1  2  1
# c  5  6  6
#
#
#
# x    1
# y    3
# d    4
# Name: b, dtype: int64

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import numpy as np
import pandas as pd

# %%
def scraping_data(input_url):
  try:
    url=input_url
    html=urlopen(url)
    soup=BeautifulSoup(html,'lxml')

    rows=soup.find_all('tr',class_='a')
    ch=['[',']','\r']
    tdata=[]
    data=[]
    for row in rows:
      row_td=str(row.find_all('td'))

      for c in ch:
        row_td=row_td.replace(c," ")
      cleantxt=BeautifulSoup(row_td,"lxml").get_text().split(", ")
      tdata.append(cleantxt)

    df=pd.DataFrame(tdata,columns=["Country","Total Covid Cases","Deaths"])
    # for  recovery_data in df:
    # df['recovery']=df['Total Covid Cases']-df['Deaths']
    # df['recovery']=pd.to_numeric(df['Total Covid Cases']-df['Deaths'])

    # print(df.head())
    print(df.dropna(axis=0))
    df.fillna(0,inplace=True)
    df['Total Covid Cases']=df['Total Covid Cases'].replace(","," ")
    # df['Total Covid Cases']=int(df['Total Covid Cases'])
    # df['recovery']=df['Total Covid Cases'].astype('int')-df['Deaths'].astype('int')
    print(df.head(20))
    # df['recovery']=data
  except Exception as e:
    return e

# %%
n=len(df)
x2=np.arange(n)

y1=df['Deaths'].astype('int')
y2=df['Total Covid Cases'].astype('int')

plt.plot(x,y1,color='r')
plt.plot(x,y2,color='b')
plt.show()

# %%
input="https://kkclasses.github.io/dsp.html"
scraping_data(input)
# Out:
# AttributeError("'tuple' object has no attribute 'startswith'")

# %%
import pandas as pd

# %%
data={
    "Name":['chandu','A','B',np.NaN],
    "Subjects":['DSP','WT','COA','CD'],
    "Marks":[90,80,45,np.NaN]
}

# %%
series_data=pd.Series(data)

# %%
student_marks=pd.DataFrame(series_data)

# %%
print(student_marks.isna())
# Out:
#               0
# Name      False
# Subjects  False
# Marks     False

# %%
df=student_marks.copy()
df
# Out:
#                             0
# Name      [chandu, A, B, nan]
# Subjects   [DSP, WT, COA, CD]
# Marks       [90, 80, 45, nan]

# %%
#removing missing data
df.dropna(axis=0,inplace=True)

# %%
#replacing missing data
df3=df.copy()
# df3['Marks'].fillna(50,inplace=True)
df3['Name']='vikram'
df3
# Out:
#                             0    Name
# Name      [chandu, A, B, nan]  vikram
# Subjects   [DSP, WT, COA, CD]  vikram
# Marks       [90, 80, 45, nan]  vikram
