# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns=30
pd.options.display.float_format='{:.2f}'.format

# %%
df=pd.read_csv('movies_complete.csv',parse_dates=["release_date"])
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 40899  378435     Whistle If You Come Back
# 40900  425498          Michael Che Matters
# 40901  359246               Hell House LLC
# 40902  347127            The Charnel House
# 40903  412698                   Libera Nos
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40904 entries, 0 to 40903
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     40904 non-null  int64
#  1   title                  40904 non-null  object
#  2   tagline                19303 non-null  object
#  3   release_date           40878 non-null  datetime64[ns]
#  4   genres                 39056 non-null  object
#  5   belongs_to_collection  4193 non-null   object
#  6   original_language      40898 non-null  object
#  7   budget_musd            8464 non-null   float64
#  8   revenue_musd           7148 non-null   float64
#  9   production_companies   30801 non-null  object
#  10  production_countries   35704 non-null  object
#  11  vote_count             40904 non-null  float64
#  12  vote_average           38629 non-null  float64
#  13  popularity             40904 non-null  float64
# ...

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  40904.00      8464.00       7148.00    40904.00      38629.00
# mean   97158.58        21.92         69.10      118.62          6.01
# std   101460.29        34.30        145.71      512.24          1.25
# min        2.00         0.00          0.00        0.00          0.00
# 25%    24199.75         2.00          2.60        4.00          5.30
# 50%    54386.00         9.00         17.36       11.00          6.10
# 75%   134318.50        26.00         68.39       38.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    40904.00 39641.00   40904.00   40903.00
# mean         3.03    98.45      12.77      10.55
# std          5.79    33.68      12.26      15.91
# min          0.00     1.00       0.00       0.00
# 25%          0.43    87.00       6.00       2.00
# ...

# %%
df.hist(figsize=(20,12),bins=10)
plt.show()

# %%
df.budget_musd.value_counts(dropna=False).head(20)
# Out:
# NaN      32440
# 5.00       262
# 10.00      248
# 20.00      235
# 15.00      221
# 2.00       220
# 3.00       208
# 25.00      201
# 30.00      184
# 1.00       182
# 4.00       167
# 12.00      167
# 6.00       165
# 40.00      160
# 8.00       153
# 35.00      141
# 0.50       130
# 7.00       130
# 50.00      122
# 1.50       114
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna=False).head(20)
# Out:
# NaN      33756
# 12.00       20
# 10.00       19
# 11.00       19
# 6.00        17
# 2.00        16
# 0.50        13
# 5.00        13
# 8.00        12
# 14.00       12
# 0.00        11
# 7.00        11
# 1.00        10
# 3.00        10
# 20.00       10
# 4.00         9
# 30.00        8
# 1.50         8
# 2.50         8
# 25.00        8
# Name: revenue_musd, dtype: int64

# %%
df.vote_count.value_counts(dropna=False).head(20)
# Out:
# 1.00     2774
# 2.00     2689
# 3.00     2404
# 0.00     2275
# 4.00     2150
# 5.00     1830
# 6.00     1537
# 7.00     1380
# 8.00     1228
# 9.00     1063
# 10.00    1048
# 11.00     839
# 12.00     769
# 13.00     672
# 14.00     634
# 15.00     615
# 16.00     567
# 17.00     520
# 18.00     462
# 20.00     426
# Name: vote_count, dtype: int64

# %%
df.vote_average.value_counts(dropna=False).head(20)
# Out:
# NaN     2275
# 6.00    2211
# 5.00    1766
# 7.00    1666
# 6.50    1574
# 6.30    1473
# 6.40    1271
# 5.50    1267
# 5.80    1265
# 6.70    1242
# 6.80    1229
# 6.60    1182
# 6.10    1179
# 6.20    1172
# 5.90    1121
# 5.70     980
# 5.30     973
# 6.90     970
# 5.60     929
# 7.30     912
# Name: vote_average, dtype: int64

# %%
df.vote_count.value_counts().head(20)
# Out:
# 1.00     2774
# 2.00     2689
# 3.00     2404
# 0.00     2275
# 4.00     2150
# 5.00     1830
# 6.00     1537
# 7.00     1380
# 8.00     1228
# 9.00     1063
# 10.00    1048
# 11.00     839
# 12.00     769
# 13.00     672
# 14.00     634
# 15.00     615
# 16.00     567
# 17.00     520
# 18.00     462
# 20.00     426
# Name: vote_count, dtype: int64

# %%
df.describe(include='object') #describing the strings data
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        40904                   19303  39056                  4193
# unique       38148                   19202   3862                  1636
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            10                       7   4553                    29
#
#        original_language       production_companies      production_countries  \
# count              40898                      30801                     35704
# unique                87                      20908                      2251
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               29444                        736                     16622
#
#                                     overview spoken_languages  \
# count                                  40119            37747
# unique                                 40099             1756
# ...

# %%
df[df.title == "Cinderella"]
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
#
#                                       genres  belongs_to_collection  \
# 984         Family|Fantasy|Animation|Romance  Cinderella Collection
# ...

# %% [markdown]
# The best and the worst movies... (part 1)

# %%
from IPython.display import HTML
pd.options.display.max_colwidth=200

# %%
df_best=df[["poster_path","title","budget_musd","revenue_musd","vote_count","vote_average","popularity"]].copy()

# %%
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 40899   <img src='http://image.tmdb.org/t/p/w185//TzMfC9C1elcrsVhVDHXpUZA2Qo.jpg' style='height:100px;'>
# 40900  <img src='http://image.tmdb.org/t/p/w185//cBO0cszPyw5ZvT2Kph7fxiemohx.jpg' style='height:100px;'>
# ...
